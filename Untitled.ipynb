# %%
import sys
sys.argv = ['']
from stroke_recognizer.train import main
main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 sys.argv = ['']
#       3 from stroke_recognizer.train import main
# ----> 4 main()
#
# File /mnt/c/Users/PerkD/documents/dev/Daber/src/stroke_recognizer/train.py:93, in main()
#      89 num_classes = len(label_names)
#      91 os.makedirs(args.save_dir, exist_ok=True)
# ---> 93 train_loader, val_loader, test_loader = build_dataloaders(
#      94     root=args.data_root, label_names=label_names, n_points=args.n_points, batch_size=args.batch_size
#      95 )
#      97 model = StrokeConvBiGRU(in_channels=9, num_classes=num_classes).to(args.device)
#      98 criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
#
# File /mnt/c/Users/PerkD/documents/dev/Daber/src/stroke_recognizer/data.py:135, in build_dataloaders(root, label_names, n_points, batch_size, num_workers)
# ...
